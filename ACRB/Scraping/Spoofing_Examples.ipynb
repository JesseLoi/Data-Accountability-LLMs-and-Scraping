# %% [markdown]
# This file gives some information on spoofing, since it will be useful text scraping large quantities of data.

# %%
url="https://d3n8a8pro7vhmx.cloudfront.net/cuapb/pages/270/attachments/original/1627046131/Minnesota_Supreme_Court__Police_can%27t_see_hotel_registries_without_reasonable_suspicion.pdf?1627046131"

#Let's try a naive technique. Let's just scrape with PyMuPDF

# %%
import pymupdf
import requests
from requests.exceptions import HTTPError
def pdf_scraper(url):
    if url=="No articles found":
        return "No articles found"

    try:
        response = requests.get(url)
        response.raise_for_status()
    except HTTPError:
        return("Access denied")
    pdf = response.content
    doc = pymupdf.open("pdf", pdf)
    text_parts = []
    if len(doc)>10:
        text_parts.append("Too_Long")
    for k in range(min(len(doc), 10)):
      text_parts.append(doc[k].get_text())
    text = "".join(text_parts)
    return text

# %%
w=pdf_scraper(url)

# %%
w
# Out:
# 'Access denied'

# %%
t=pdf_scraper("https://acrbgov.org/wp-content/uploads/2023/02/To-APD-Chief-RE-ACRB-Case-No.-22-018.pdf")

# %%
t
# Out:
# 'Access denied'

# %%
#Let's add a header


def pdf_scraper2(url):
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://www.google.com/"
    }
    if url=="No articles found":
        return "No articles found"

    try:
        response = requests.get(url, headers=headers)
        print(response.raise_for_status())
    except HTTPError:
        print(response.raise_for_status())
        return(HTTPError)
        
    pdf = response.content
    doc = pymupdf.open("pdf", pdf)
    text_parts = []
    if len(doc)>10:
        text_parts.append("Too_Long")
    for k in range(min(len(doc), 10)):
      text_parts.append(doc[k].get_text())
    text = "".join(text_parts)
    return text

# %%
pdf_scraper2("https://acrbgov.org/wp-content/uploads/2023/02/To-APD-Chief-RE-ACRB-Case-No.-22-018.pdf")
# Out:
# None
# ...

# %%
pdf_scraper2(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 15, in pdf_scraper2(url)
#      14     response = requests.get(url, headers=headers)
# ---> 15     print(response.raise_for_status())
#      16 except HTTPError:
#
# File c:\Users\Jesse\anaconda3\envs\SU_MSDS\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://d3n8a8pro7vhmx.cloudfront.net/cuapb/pages/270/attachments/original/1627046131/Minnesota_Supreme_Court__Police_can%27t_see_hotel_registries_without_reasonable_suspicion.pdf?1627046131
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pdf_scraper2(url)
#
# ...
