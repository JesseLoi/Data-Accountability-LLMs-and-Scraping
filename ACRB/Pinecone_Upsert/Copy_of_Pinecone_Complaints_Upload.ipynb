# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")  # dimension is 384

# %%
import pandas as pd

df = pd.read_csv("2025_complaints_scraped.csv")

texts = df.apply(lambda row: " | ".join(map(str, row.values)), axis=1).tolist()

# %%
vectors = model.encode(texts, convert_to_numpy=True)
#embeddings = model.encode(texts, convert_to_numpy=True)

# %%
#!pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2025.10.5)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl.metadata (30 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2.5.0)
# Collecting packaging<25.0,>=24.2 (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.11)
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 43.5 MB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 26.1 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: pinecone-plugin-interface, packaging, pinecone-plugin-assistant, pinecone
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed packaging-24.2 pinecone-7.3.0 pinecone-plugin-assistant-1.8.0 pinecone-plugin-interface-0.0.7

# %%
from pinecone import Pinecone
import os
#api key goes here
pc = Pinecone(api_key="")
index_name = "2025test"

index = pc.Index(index_name)

# %%
import math

def chunk_text(text, chunk_size=400, overlap=50):
    words = text.split()
    step = chunk_size - overlap
    chunks = []
    for i in range(0, max(1, len(words)), step):
        chunk = " ".join(words[i:i+chunk_size])
        if not chunk:
            break
        start_word = i
        end_word = i + len(chunk.split()) - 1
        chunks.append((chunk, start_word, end_word))
        if len(words) <= i + chunk_size:
            break
    return chunks

# %%
def upsert_in_batches(index, items, batch_size=100):
    for i in range(0, len(items), batch_size):
        batch = items[i:i+batch_size]
        index.upsert(batch)

# %%
index.delete(delete_all=True)
print(index.describe_index_stats())
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np

items = []
for row_idx, row in df.iterrows():
    doc_id = f"r{row_idx}"
    date = row["Date"]
    p_tags = row["P_tags"]
    l_tags = row["LI_tags"]
    url_text = row["URL_Text"]
    url_raw = row["URLs"]
    text = row["Text"]
    chunks = chunk_text(text, chunk_size=300, overlap=50)
    for chunk_idx, (chunk, start, end) in enumerate(chunks):
        excerpt = chunk[:300]
        metadata = {
            "doc_id": doc_id,
            "row": row_idx,
             "date": date,
             "url": url_raw,
             "url_text": url_text,
             "p_tags": p_tags,
             "l_tags": l_tags,
             "start": start,
             "end": end,
            "excerpt": excerpt[:250]
        }

        items.append({
            "doc_id": doc_id,
            "row_idx": row_idx,
            "chunk_idx": chunk_idx,
            "text": chunk,
            "metadata": metadata
        })
payloads = []
batch_size_encode = 64
for i in range(0, len(items), batch_size_encode):
    batch = items[i:i+batch_size_encode]
    texts = [it["text"] for it in batch]
    embs = model.encode(texts, batch_size=32, convert_to_numpy=True)
    for j, it in enumerate(batch):
        if len(embs[j].tolist())==[]:
          print("Error")
        payloads.append({
            "id": f"{it['doc_id']}-{it['chunk_idx']}",
            "values": embs[j].tolist(),
            "metadata": it["metadata"]
        })
upsert_in_batches(index, payloads, batch_size=25)

# %%
q_vec = model.encode("Abusive language", convert_to_numpy=True).tolist()
res = index.query(vector=q_vec, top_k=10, include_metadata=True)

# %%
res
# Out:
# {'matches': [{'id': 'r25-1',
#               'metadata': {'date': '08-May-2025',
#                            'doc_id': 'r25',
#                            'end': 432.0,
#                            'excerpt': 'a finding of “Sustained” and '
#                                       'recommends, as penalty, a 4-Day '
#                                       'Suspension and Training on APD’s '
#                                       'policies governing Use of Force. 3. The '
#                                       'allegation of Abusive Language be '
#                                       'assigned a finding of “Sustained” and '
#                                       'recommends, as penalty, a Written '
#                                       'Reprimand ',
#                            'l_tags': "['Appropriate Action Required', "
#                                      "'Excessive Force', 'Abusive Language']",
#                            'p_tags': "['08-May-2025', 'Case #24-157', 'Board "
#                                      "Letter to the Chief (pdf)', 'APD Chief "
#                                      "Preliminary Response (pdf)']",
#                            'row': 25.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/05/Board-Letter-to-Chief.Case-No.24-157.pdf',
#                            'url_text': 'Board Letter to the Chief (pdf)'},
#               'score': 0.344027519,
#               'values': []},
#              {'id': 'r27-1',
#               'metadata': {'date': '10-July-2025',
#                            'doc_id': 'r27',
#                            'end': 444.0,
#                            'excerpt': 'investigation claim be assigned a '
#                                       'finding of “Sustained” and recommends, '
#                                       'as penalty, a Written Reprimand and '
#                                       'Training on Investigative Procedures. '
#                                       '2. The allegation of Abusive Language '
#                                       'related to the officer’s insensitive '
#                                       'and unprofessional conduct b',
#                            'l_tags': "['Appropriate Action Required', 'Abusive "
#                                      "Language', 'Violation of SOP']",
#                            'p_tags': "['10-July-2025', 'Case #24-029', 'Board "
#                                      "Letter to the Chief (pdf)', 'APD Chief "
#                                      "Preliminary Response (pdf)']",
#                            'row': 27.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/07/Board-Letter-to-Chief.Case-No.24-029.pdf',
#                            'url_text': 'Board Letter to the Chief (pdf)'},
#               'score': 0.280151397,
#               'values': []},
#              {'id': 'r17-1',
#               'metadata': {'date': '24-April-2025 (Review Panel)',
#                            'doc_id': 'r17',
#                            'end': 504.0,
#                            'excerpt': 'investigation determined that Officers '
#                                       'Thomas Hoffman (Unique ID No. 7859) and '
#                                       'John Hordesky (Unique ID No. 7116) were '
#                                       'involved in this incident and were '
#                                       'treated as the subjects of this '
#                                       'investigation. The Board determined the '
#                                       'following for both Offic',
#                            'l_tags': "['False Imprisonment', 'Abusive "
#                                      "Language', 'Violation of SOP', "
#                                      "'Excessive Force']",
#                            'p_tags': "['24-April-2025 (Review Panel)', 'Case "
#                                      "#23-196', 'Board Letter to the Chief "
#                                      "(pdf)', 'Chief Preliminary Response "
#                                      "(pdf)']",
#                            'row': 17.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/05/Board-Letter-to-Chief.Case-No.23-196.pdf',
#                            'url_text': 'Board Letter to the Chief (pdf)'},
#               'score': 0.248085976,
#               'values': []},
#              {'id': 'r26-0',
#               'metadata': {'date': '08-May-2025',
#                            'doc_id': 'r26',
#                            'end': 154.0,
#                            'excerpt': '[\'\', "ode Dickens ‘sana Posce '
#                                       'Deparment\\n‘aro ‘ain Sclet\\n\\n‘Ei ol '
#                                       'Foes\\n\\nMe Germalne Austin, '
#                                       'Chae\\n‘Alana Caen Review Board\\n{ky '
#                                       'Hal Tower ait 9100,\\n‘55 Tent Avenue, '
#                                       'SW,\\n‘Adan, Ga 30308\\n\\nRe ACRB Fle '
#                                       '24-157\\n‘ear Mr. Germaine '
#                                       'Aust\\n\\n{am inceeip',
#                            'l_tags': "['Appropriate Action Required', "
#                                      "'Excessive Force', 'Abusive Language']",
#                            'p_tags': "['08-May-2025', 'Case #24-157', 'Board "
#                                      "Letter to the Chief (pdf)', 'APD Chief "
#                                      "Preliminary Response (pdf)']",
#                            'row': 26.0,
#                            'start': 0.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/05/APD-Chief-PRELIMINARY-Response-24-157.pdf',
#                            'url_text': 'APD Chief Preliminary Response (pdf)'},
#               'score': 0.196087837,
#               'values': []},
#              {'id': 'r8-0',
#               'metadata': {'date': '9-January-2025',
#                            'doc_id': 'r8',
#                            'end': 202.0,
#                            'excerpt': "['', 'RECEIVED 7/31/25 BY SR\\n\\nCITY "
#                                       'OF ATLANTA\\n\\note Dt roi ee 3 ga '
#                                       'gD\\n{aoe soto ‘Chef ot Poe\\n|\\nJuly '
#                                       '30, 2025\\nMe. Kevin Wins\\n‘Alta '
#                                       'Chizen Review Board\\nCy Hal Tower: '
#                                       'Suse 9100\\n\\n58 Tal Avenue, '
#                                       'SW.\\n‘Anta, Ga 30305\\n\\nRe: ACRB '
#                                       'Piet 23-204\\nDea',
#                            'l_tags': "['Conduct']",
#                            'p_tags': "['Case #23-204', 'Board Letter to Chief "
#                                      "(pdf)', 'APD Chief Preliminary Decision "
#                                      "(pdf)', 'Chief Final Decision (pdf)']",
#                            'row': 8.0,
#                            'start': 0.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/08/APD-Chief-FINAL-Decision-23-204.pdf',
#                            'url_text': 'Chief Final Decision (pdf)'},
#               'score': 0.192994595,
#               'values': []},
#              {'id': 'r39-0',
#               'metadata': {'date': '23-July-2025',
#                            'doc_id': 'r39',
#                            'end': 162.0,
#                            'excerpt': '[\'\', "RECEIVED 8/4/25 BY SR\\n\\nCITY '
#                                       'OF ATLANTA\\n\\ngon grea sang bent\\naa '
#                                       '“sae er\\n\\n‘aust 01, 2025,\\nMe Kevin '
#                                       'Wiliams Chir\\n\\n‘Alana Cizen Review '
#                                       'Board\\n\\nCy Hal Tower Suit '
#                                       '9100,\\n\\n55 Tanly Avenue, '
#                                       'SW.\\n\\n‘Adana, Ga 30303,\\n\\nRe: '
#                                       'AGRB Filet 24-207\\n',
#                            'l_tags': "['Appropriate Action Required', "
#                                      "'Conduct', 'Violation of SOP']",
#                            'p_tags': "['Case #24-207', 'Board Letter to the "
#                                      "Chief (pdf)', 'APD Chief Preliminary "
#                                      "Response (pdf)']",
#                            'row': 39.0,
#                            'start': 0.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/08/APD-PRELIMINARY-Response-24-207.pdf',
#                            'url_text': 'APD Chief Preliminary Response (pdf)'},
#               'score': 0.185706139,
#               'values': []},
#              {'id': 'r40-1',
#               'metadata': {'date': '11-September-2025',
#                            'doc_id': 'r40',
#                            'end': 480.0,
#                            'excerpt': 'allegation of Violation of Department '
#                                       'Standard Operating Procedures related '
#                                       'to the second citation issue be '
#                                       'assigned a finding of “Exonerated.” The '
#                                       'Board further determined that APD’s '
#                                       'directive, as of March 18, 2025 (see '
#                                       'Exhibit 10 in the Investigati',
#                            'l_tags': "['False Imprisonment', 'Violation of "
#                                      "SOP']",
#                            'p_tags': "['11-September-2025', 'Case #25-111', "
#                                      "'Board Letter to the Chief (pdf)']",
#                            'row': 40.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/09/Board-Letter-to-APD-Chief-Case-No.25-111.pdf',
#                            'url_text': 'Board Letter to the Chief (pdf)'},
#               'score': 0.183633804,
#               'values': []},
#              {'id': 'r3-0',
#               'metadata': {'date': '9-January-2025',
#                            'doc_id': 'r3',
#                            'end': 227.0,
#                            'excerpt': "['', 'RECEIVED 7/31/25 BY SR\\n\\nCITY "
#                                       'OF ATLANTA\\n\\nates 226 rece Seew SW '
#                                       '‘aga Poe Deprnet\\nMore er "Coat '
#                                       'oetce\\nMe Kelvin Wiliams\\n\\n‘lant '
#                                       'Chin Review Board\\nCay Hal Tomer: Suse '
#                                       '9100,\\n55 Tinky Avenue, SW.\\n‘Alana, '
#                                       'Ge 30303\\n\\nes ACR Fle 23-092\\nDear',
#                            'l_tags': "['False Imprisonment', 'Appropriate "
#                                      "Action Required', 'Violation of SOP']",
#                            'p_tags': "['Case #23-092', 'Board Letter to Chief "
#                                      "(pdf)', 'Chief Preliminary Response "
#                                      "(pdf)', 'Chief Final Decision (pdf)']",
#                            'row': 3.0,
#                            'start': 0.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/08/APD-Chief-FINAL-Decision-23-092.pdf',
#                            'url_text': 'Chief Final Decision (pdf)'},
#               'score': 0.182941437,
#               'values': []},
#              {'id': 'r1-1',
#               'metadata': {'date': '9-January-2025',
#                            'doc_id': 'r1',
#                            'end': 523.0,
#                            'excerpt': '(Unique ID No. 7745), and Lieutenant '
#                                       'Donovan Clements (Unique ID No. 4897) '
#                                       'were involved in this incident and were '
#                                       'treated as the subjects of this '
#                                       'investigation. The Board determined the '
#                                       'following: 1. The allegation of False '
#                                       'Imprisonment related to t',
#                            'l_tags': "['False Imprisonment', 'Appropriate "
#                                      "Action Required', 'Violation of SOP']",
#                            'p_tags': "['Case #23-092', 'Board Letter to Chief "
#                                      "(pdf)', 'Chief Preliminary Response "
#                                      "(pdf)', 'Chief Final Decision (pdf)']",
#                            'row': 1.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/02/Board-Letter-to-Chief.Case-No.-23-092.pdf',
#                            'url_text': 'Board Letter to Chief (pdf)'},
#               'score': 0.156659141,
#               'values': []},
#              {'id': 'r38-1',
#               'metadata': {'date': '23-July-2025',
#                            'doc_id': 'r38',
#                            'end': 538.0,
#                            'excerpt': 'involved in this incident and was, '
#                                       'therefore, also treated as a subject in '
#                                       'this investigation. The Board '
#                                       'determined the following for Officer '
#                                       'Jason Whitehead: 1. The allegation of '
#                                       'Appropriate Action Required related to '
#                                       'the inadequate investigation cl',
#                            'l_tags': "['Appropriate Action Required', "
#                                      "'Conduct', 'Violation of SOP']",
#                            'p_tags': "['Case #24-207', 'Board Letter to the "
#                                      "Chief (pdf)', 'APD Chief Preliminary "
#                                      "Response (pdf)']",
#                            'row': 38.0,
#                            'start': 250.0,
#                            'url': 'https://acrbgov.org/wp-content/uploads/2025/08/Board-Letter-to-APDChiefCase-No.24-207.pdf',
#                            'url_text': 'Board Letter to the Chief (pdf)'},
#               'score': 0.156441689,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 1}}
